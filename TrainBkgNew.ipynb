# %% [markdown]
# # Hit classification

# %% [markdown]
# Set initial variables for the "suffix" identifier for the data set and "filePath" the relative path to the data files. Remember to add "/" to the end of your path, for example "../../TrkAna/43291981/"

# %% [markdown]
# In this notebook we use Keras and XGBoost to distinguish between hits from conversion electrons and hits from other particles

# %%
import os
import uproot 
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import datetime
import tensorflow as tf
from pathlib import Path
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, ReLU
from tensorflow.keras.optimizers import SGD
import tensorflow.keras.layers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier
#import onnx
#import tf2onnx

# %%
rm -rf ./logs/

# %% [markdown]
# In our problem we have a different number of signal and background entries in our input dataset. There are several techniques avaialable for _unbalanced_ datasets. Here we are using the most naive one, which is just using $\min(N_{sig}, N_{bkg})$ events. Then, we divide our input into the _training_, _validation_, and _test_ datasets.  Note that the datasets must be pruned to the nearest multiple of the batch size, otherwise the gradient calculation fails.

# %%
input_dataset = np.empty
temp = np.empty
signal = np.empty
backgnd = np.empty
files = ["/global/cfs/cdirs/m3712/Mu2e/TA_CeEndpointMix1BBTriggerable.MDC2020ae_best_v1_3.root"] #With offsets
#files = ["/global/u2/j/jasonguo/KKTrain/TADeMCeEDigis.root"]
#files = ["/global/cfs/cdirs/m3712/Mu2e/TADeM_CeEndpointMix1BBTriggerable.MDC2020ae_perfect_v1_3.root"] #without offsets
suffix = "WithOffsets"


data_fields = ["state", "udoca", "cdrift", "rdrift", "tottdrift", "wdot", "udocavar", "wdist", "uupos", "poca"]
mc_fields = ["rel"]

a = {field: [] for field in data_fields}
for field in mc_fields:
    a[field] = []
    
for batch in uproot.iterate(files,filter_name="/trk|trktsh|trktshmc/i"):
    #print("Fields available in 'trktsh':", ak.fields(batch["trktshmc"]))
    #cut = ak.sum(batch["trk.status"],axis=1) == 1
    
    cut = ((ak.sum(batch["trk.status"],axis=1) > 0) & ak.sum(batch["trk.goodfit"],axis=1)) == 1 #& 
           #(ak.sum(batch["trktshmc"]["startCode"], axis=1) == 167)) == 1
    
    batch["trktshmc"]["startCode"].type.show()
    #cut2 = ak.flatten(ak.flatten(batch["trktshmc"]["startCode"][ak.local_index(batch["trktshmc"]["startCode"]) < ak.num(batch["trktsh"]
    #        [data_fields[0]], axis = 2)][cut])).to_numpy()
    #cut2 = (cut2 == 167)
    for field in data_fields:
        a[field].append(ak.flatten(ak.flatten(batch["trktsh"][field][cut])).to_numpy())
    for field in mc_fields:
        a[field].append(ak.flatten(ak.flatten(batch["trktshmc"][field][ak.local_index(batch["trktshmc"][field]) < ak.num(batch["trktsh"]
            [data_fields[0]], axis = 2)][cut])).to_numpy())
for field in a:
    a[field] = np.concatenate(a[field])
    
udoca = np.absolute(a["udoca"])
sint = np.sqrt(1.0-a["wdot"]*a["wdot"])
plen = 6.25-a["cdrift"]*a["cdrift"]
pmin = np.repeat(0.25,plen.shape[0])
plen = np.sqrt(np.maximum(plen,pmin))
a["udocavar"] = np.absolute(a["udocavar"])
udocasig = np.sqrt(a["udocavar"])
print(a["poca"][0][0][0])
rho = np.array([np.sqrt(np.square(x[0][0]) + np.square(x[0][1])) for x in a["poca"]])
du = np.absolute(a["wdist"] - a["uupos"])


temp = np.vstack((udoca, a["cdrift"], udocasig, a["tottdrift"], du, rho)).T
if input_dataset is np.empty:
    input_dataset = temp
else:
    input_dataset = np.concatenate((input_dataset, temp))


#print("Processed file " + filename + " with %s hits"%a['state'].shape[0])
#print(a["rel"].shape)
#print(a["state"].shape)
#print (len(a["rel"]))
#print (len(a["state"]))
mcrel = np.array([x[0] for x in a["rel"]])
rand = np.random.random_sample([mcrel.shape[0]])

#print(udoca)
sig = (a["state"]>=-2) & (rand<0.05) & (mcrel==0) & (udoca < 50.0) & (du < 3000.0)
bkg = (a["state"]>=-2) & (mcrel==-1) & (udoca < 50.0) & ( du < 3000.0)
#print (np.sum(sig))
if signal is np.empty:
    signal = sig
    backgnd = bkg
else:
    signal = np.concatenate((signal,sig))
    backgnd = np.concatenate((backgnd,bkg))
        
nhits=len(input_dataset)
nsignal=signal.sum()
nbackgnd=backgnd.sum()
print("Total dataset %s hits, %s signal and %s background"%(nhits,nsignal,nbackgnd))
# Out:
# 8221 * var * var * int32
# 8221 * var * var * int32
# 8221 * var * var * int32
# 5280 * var * var * int32
# -184.94162
# Total dataset 1070059 hits, 50358 signal and 24358 background

# %%
min_len = min(len(input_dataset[signal]), len(input_dataset[backgnd]))
bsize=32
# I need to double the batch_size when truncating as we divide the sample in half later for training
tsize=2*bsize
min_len = (min_len - min_len%tsize)
print("Training on %s matched hits"%min_len)
signal_dataset = input_dataset[signal][:min_len]
bkg_dataset = input_dataset[backgnd][:min_len]

balanced_input = np.concatenate((signal_dataset, bkg_dataset))
y_balanced_input = np.concatenate((np.ones(signal_dataset.shape[0]), np.zeros(bkg_dataset.shape[0])))

n_variables = balanced_input.shape[1]

x_ce_train, x_ce_test, y_ce_train, y_ce_test = train_test_split(balanced_input, y_balanced_input, test_size=0.5, random_state=42)
x_ce_test, x_ce_valid, y_ce_test, y_ce_valid = train_test_split(x_ce_test, y_ce_test, test_size=0.5, random_state=42)
# Out:
# Training on 24320 matched hits

# %%
udoca_sig = []
udoca_back = []

for i in range(x_ce_train.shape[0]):
    if y_ce_train[i] == 1:
        udoca_sig.append(x_ce_train[i][0])
    else:
        udoca_back.append(x_ce_train[i][0])
plt.hist(udoca_sig,label="Unbiased DOCA Signal" + suffix, bins=100,range=(0,15))
plt.hist(udoca_back,label="Unbiased DOCA Background" + suffix, histtype='step', bins=100,range=(0,15))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
udoca_sig = []
tottdrift_sig = []
cdrift_sig = []
udocasig_sig = []
du_sig = []
rho_sig = []

for i in range(signal_dataset.shape[0]):
    udoca_sig.append(signal_dataset[i][0])
    
for i in range(signal_dataset.shape[0]):
    cdrift_sig.append(signal_dataset[i][1])
    
for i in range(signal_dataset.shape[0]):
    udocasig_sig.append(signal_dataset[i][2])

for i in range(signal_dataset.shape[0]):
    tottdrift_sig.append(signal_dataset[i][3])

for i in range(signal_dataset.shape[0]):
    du_sig.append(signal_dataset[i][4])

for i in range(signal_dataset.shape[0]):
    rho_sig.append(signal_dataset[i][5])

# %%
udoca_back = []
tottdrift_back = []
cdrift_back = []
udocasig_back = []
du_back = []
rho_back = []
    
for i in range(bkg_dataset.shape[0]):
    udoca_back.append(bkg_dataset[i][0])
    
for i in range(bkg_dataset.shape[0]):
    cdrift_back.append(bkg_dataset[i][1])
    
for i in range(bkg_dataset.shape[0]):
    udocasig_back.append(bkg_dataset[i][2])

for i in range(bkg_dataset.shape[0]):
    tottdrift_back.append(bkg_dataset[i][3])
    
for i in range(bkg_dataset.shape[0]):
    du_back.append(bkg_dataset[i][4])
    
for i in range(bkg_dataset.shape[0]):
    rho_back.append(bkg_dataset[i][5])

# %%
plt.hist(udoca_sig,label="Unbiased DOCA Signal", bins=100,range=(0,15))
plt.hist(udoca_back,label="Unbiased DOCA Background", histtype='step', bins=100,range=(0,15))
plt.legend()
plt.show
plt.savefig(f"plots/UnbiasedDOCA{suffix}.pdf")

# %%
plt.hist(cdrift_sig,label="Drift Radius Signal", bins=100,range=(-3.0,5.0))
plt.hist(cdrift_back,label="Drift Radius Background", histtype='step', bins=100, range=(-3.0,5.0))
plt.legend()
plt.show
plt.savefig(f"plots/DriftRadius{suffix}.pdf")

# %%
plt.hist(udocasig_sig,label="DOCA Variance Signal", bins=50,range=(0,5))
plt.hist(udocasig_back,label="DOCA Variance Background", histtype='step', bins=50,range=(0,5))
plt.legend()
plt.show
plt.savefig(f"plots/DOCAVariance{suffix}.pdf")

# %%
plt.hist(tottdrift_sig,label="Time-Over-Threshold Drift Time Signal", bins=50, range=(0,40))
plt.hist(tottdrift_back,label="Time-Over-Threshold Drift Time Background", histtype='step', bins=50,range=(0,40))
plt.legend()
plt.show
plt.savefig(f"plots/TOTDrift{suffix}.pdf")

# %%
plt.hist(du_sig,label="WDist - Unbiased U Position Difference Signal", bins=50, range=(0,800))
plt.hist(du_back,label="WDist - Unbiased U Position Difference Background", histtype='step', bins=50, range=(0,800))
plt.legend()
plt.show
plt.savefig(f"plots/WDist{suffix}.pdf")

# %%
plt.hist(rho_sig,label="Rho Signal", bins=50, range=(350,700))
plt.hist(rho_back,label="Rho Background", histtype='step', bins=50, range=(350,700))
plt.legend()
plt.show
plt.savefig(f"plots/RhoSig{suffix}.pdf")

# %% [markdown]
# Then, we concatenate each hit variables into a single, large numpy array. These arrays are then stacked in a single bi-dimensional array with `np.vstack`, which will be our input dataset used for the training of the machine learning algorithms.

# %% [markdown]
# Here we then assign a label to each hit as _signal_ or _background_, depending on the Monte Carlo truth information. Since the dimension of  `detshmc.rel._rel` is not guaranteed to be the same as the dimension of `detsh` we need to loop over all the entries.

# %% [markdown]
# ## Create and train a multi-layer perceptron

# %% [markdown]
# Here we create a _multi-layer perceptron_ (MLP) model which consists of 3 fully-connected (or _dense_) layers, each one followed by a _dropout_ layer, which helps to avoid overfitting. The model is trained using the [Adam](https://arxiv.org/abs/1412.6980) optimizer and trained for 50 epochs or until the validation loss doesn't improve for 5 epochs (`early_stop`). The model we save must be created first, with an explicit input layer with explicit batch_size, otherwise it can't be parsed by the TMVA::SOFIE parser we use to generate a C++ inference function downstream.

# %% [markdown]
# The output model must have batch_size=1, otherwise the SOFIE inference function will assume that many input variables at a time.  Training (gradient calculation) however is much more efficient with a larger batch size, so we construct a separate model for that.  After training and before saving, we'll copy the weights (which don't depend on batch_size) from the trained model to the output model.  This should be unnecessary in the next verison of ROOT.
#
# We should initialize the model by reading a previous iteration. TODO

# %%
# load previous training if it exists
modelfile = "models/TrainBkg" + suffix + ".h5"
if False:
    model = keras.models.load_model(modelfile)
    print("Loading model from file " +modelfile)
else:
    print("Creating model " +modelfile)
    lay0=Input(shape=(n_variables,),batch_size=bsize)
    lay1=Dense(2*n_variables, activation='relu')(lay0)
    lay2=Dense(2*n_variables, activation='relu')(lay1)
    lay3=Dense(2*n_variables, activation='relu')(lay2)
    lay4=Dense(1,activation='sigmoid')(lay3)
    model=Model(inputs=lay0,outputs=lay4)

opt = Adam(learning_rate=1e-3)
model.compile(loss='binary_crossentropy',metrics='accuracy',optimizer=opt)
early_stop = EarlyStopping(monitor='val_loss', patience=20, min_delta=1e-5, restore_best_weights=True)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tensorflow.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(x_ce_train, y_ce_train,
                          batch_size=bsize,
                          epochs=200,
                          verbose=1,
                          validation_data=(x_ce_valid, y_ce_valid),
                          callbacks=[early_stop, tensorboard_callback]
                         )
# Out:
# Creating model models/TrainBkgWithOffsets.h5
# Epoch 1/200
# 760/760 [==============================] - 2s 2ms/step - loss: 1.6865 - accuracy: 0.8405 - val_loss: 0.3608 - val_accuracy: 0.8378
# Epoch 2/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.2551 - accuracy: 0.9093 - val_loss: 0.2072 - val_accuracy: 0.9184
# Epoch 3/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.2036 - accuracy: 0.9327 - val_loss: 0.1875 - val_accuracy: 0.9477
# Epoch 4/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1904 - accuracy: 0.9388 - val_loss: 0.1946 - val_accuracy: 0.9544
# Epoch 5/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1777 - accuracy: 0.9461 - val_loss: 0.1523 - val_accuracy: 0.9552
# Epoch 6/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1770 - accuracy: 0.9474 - val_loss: 0.1448 - val_accuracy: 0.9560
# Epoch 7/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1782 - accuracy: 0.9493 - val_loss: 0.1787 - val_accuracy: 0.9542
# Epoch 8/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1716 - accuracy: 0.9535 - val_loss: 0.2190 - val_accuracy: 0.9345
# Epoch 9/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1660 - accuracy: 0.9541 - val_loss: 0.1418 - val_accuracy: 0.9625
# Epoch 10/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1739 - accuracy: 0.9520 - val_loss: 0.1726 - val_accuracy: 0.9532
# Epoch 11/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1704 - accuracy: 0.9521 - val_loss: 0.1413 - val_accuracy: 0.9610
# Epoch 12/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1662 - accuracy: 0.9553 - val_loss: 0.1470 - val_accuracy: 0.9576
# Epoch 13/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1644 - accuracy: 0.9545 - val_loss: 0.3205 - val_accuracy: 0.9011
# Epoch 14/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1687 - accuracy: 0.9532 - val_loss: 0.1576 - val_accuracy: 0.9550
# Epoch 15/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1663 - accuracy: 0.9549 - val_loss: 0.1505 - val_accuracy: 0.9566
# Epoch 16/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1686 - accuracy: 0.9538 - val_loss: 0.1419 - val_accuracy: 0.9602
# Epoch 17/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1660 - accuracy: 0.9538 - val_loss: 0.1685 - val_accuracy: 0.9549
# Epoch 18/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1613 - accuracy: 0.9551 - val_loss: 0.1850 - val_accuracy: 0.9470
# Epoch 19/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1615 - accuracy: 0.9538 - val_loss: 0.1757 - val_accuracy: 0.9443
# Epoch 20/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1577 - accuracy: 0.9550 - val_loss: 0.1383 - val_accuracy: 0.9613
# Epoch 21/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1575 - accuracy: 0.9542 - val_loss: 0.1558 - val_accuracy: 0.9537
# Epoch 22/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1499 - accuracy: 0.9582 - val_loss: 0.1398 - val_accuracy: 0.9589
# Epoch 23/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1513 - accuracy: 0.9584 - val_loss: 0.1388 - val_accuracy: 0.9626
# Epoch 24/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1527 - accuracy: 0.9569 - val_loss: 0.1667 - val_accuracy: 0.9539
# Epoch 25/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1481 - accuracy: 0.9580 - val_loss: 0.1377 - val_accuracy: 0.9597
# Epoch 26/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1494 - accuracy: 0.9570 - val_loss: 0.1678 - val_accuracy: 0.9523
# Epoch 27/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1442 - accuracy: 0.9583 - val_loss: 0.1799 - val_accuracy: 0.9474
# Epoch 28/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1409 - accuracy: 0.9606 - val_loss: 0.1447 - val_accuracy: 0.9570
# Epoch 29/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1316 - accuracy: 0.9614 - val_loss: 0.1130 - val_accuracy: 0.9648
# Epoch 30/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1328 - accuracy: 0.9604 - val_loss: 0.1128 - val_accuracy: 0.9646
# Epoch 31/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1279 - accuracy: 0.9609 - val_loss: 0.1256 - val_accuracy: 0.9641
# Epoch 32/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1275 - accuracy: 0.9619 - val_loss: 0.1106 - val_accuracy: 0.9651
# Epoch 33/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1292 - accuracy: 0.9614 - val_loss: 0.1085 - val_accuracy: 0.9665
# Epoch 34/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1243 - accuracy: 0.9632 - val_loss: 0.1369 - val_accuracy: 0.9560
# Epoch 35/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1281 - accuracy: 0.9620 - val_loss: 0.1241 - val_accuracy: 0.9614
# Epoch 36/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1256 - accuracy: 0.9623 - val_loss: 0.1090 - val_accuracy: 0.9660
# Epoch 37/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1214 - accuracy: 0.9630 - val_loss: 0.1195 - val_accuracy: 0.9607
# Epoch 38/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1225 - accuracy: 0.9638 - val_loss: 0.1087 - val_accuracy: 0.9660
# Epoch 39/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1217 - accuracy: 0.9645 - val_loss: 0.1514 - val_accuracy: 0.9627
# Epoch 40/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1236 - accuracy: 0.9630 - val_loss: 0.1291 - val_accuracy: 0.9641
# Epoch 41/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1234 - accuracy: 0.9627 - val_loss: 0.1583 - val_accuracy: 0.9502
# Epoch 42/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1257 - accuracy: 0.9622 - val_loss: 0.1284 - val_accuracy: 0.9642
# Epoch 43/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1204 - accuracy: 0.9640 - val_loss: 0.1223 - val_accuracy: 0.9617
# Epoch 44/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1174 - accuracy: 0.9648 - val_loss: 0.1494 - val_accuracy: 0.9592
# Epoch 45/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1206 - accuracy: 0.9653 - val_loss: 0.1121 - val_accuracy: 0.9669
# Epoch 46/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1235 - accuracy: 0.9639 - val_loss: 0.1089 - val_accuracy: 0.9666
# Epoch 47/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1212 - accuracy: 0.9634 - val_loss: 0.1535 - val_accuracy: 0.9519
# Epoch 48/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1183 - accuracy: 0.9646 - val_loss: 0.1093 - val_accuracy: 0.9661
# Epoch 49/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1193 - accuracy: 0.9642 - val_loss: 0.1161 - val_accuracy: 0.9669
# Epoch 50/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1158 - accuracy: 0.9652 - val_loss: 0.1548 - val_accuracy: 0.9515
# Epoch 51/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1179 - accuracy: 0.9648 - val_loss: 0.1122 - val_accuracy: 0.9658
# Epoch 52/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1215 - accuracy: 0.9636 - val_loss: 0.1356 - val_accuracy: 0.9581
# Epoch 53/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1154 - accuracy: 0.9660 - val_loss: 0.1076 - val_accuracy: 0.9670
# Epoch 54/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1190 - accuracy: 0.9652 - val_loss: 0.1129 - val_accuracy: 0.9664
# Epoch 55/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1151 - accuracy: 0.9651 - val_loss: 0.1242 - val_accuracy: 0.9592
# Epoch 56/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1168 - accuracy: 0.9653 - val_loss: 0.1168 - val_accuracy: 0.9649
# Epoch 57/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1159 - accuracy: 0.9653 - val_loss: 0.1045 - val_accuracy: 0.9674
# Epoch 58/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1157 - accuracy: 0.9656 - val_loss: 0.1057 - val_accuracy: 0.9674
# Epoch 59/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1166 - accuracy: 0.9654 - val_loss: 0.1068 - val_accuracy: 0.9684
# Epoch 60/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1161 - accuracy: 0.9655 - val_loss: 0.1130 - val_accuracy: 0.9656
# Epoch 61/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1167 - accuracy: 0.9645 - val_loss: 0.1131 - val_accuracy: 0.9674
# Epoch 62/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1137 - accuracy: 0.9656 - val_loss: 0.1074 - val_accuracy: 0.9679
# Epoch 63/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1127 - accuracy: 0.9662 - val_loss: 0.1125 - val_accuracy: 0.9660
# Epoch 64/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1141 - accuracy: 0.9653 - val_loss: 0.1130 - val_accuracy: 0.9664
# Epoch 65/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1126 - accuracy: 0.9662 - val_loss: 0.1037 - val_accuracy: 0.9683
# Epoch 66/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1124 - accuracy: 0.9664 - val_loss: 0.1121 - val_accuracy: 0.9690
# Epoch 67/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1120 - accuracy: 0.9663 - val_loss: 0.1061 - val_accuracy: 0.9681
# Epoch 68/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1134 - accuracy: 0.9662 - val_loss: 0.1058 - val_accuracy: 0.9692
# Epoch 69/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1127 - accuracy: 0.9662 - val_loss: 0.1276 - val_accuracy: 0.9576
# Epoch 70/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1141 - accuracy: 0.9653 - val_loss: 0.1034 - val_accuracy: 0.9675
# Epoch 71/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1090 - accuracy: 0.9668 - val_loss: 0.1182 - val_accuracy: 0.9638
# Epoch 72/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1149 - accuracy: 0.9652 - val_loss: 0.1029 - val_accuracy: 0.9684
# Epoch 73/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1113 - accuracy: 0.9668 - val_loss: 0.1160 - val_accuracy: 0.9636
# Epoch 74/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1121 - accuracy: 0.9660 - val_loss: 0.1081 - val_accuracy: 0.9669
# Epoch 75/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1118 - accuracy: 0.9670 - val_loss: 0.1022 - val_accuracy: 0.9691
# Epoch 76/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1086 - accuracy: 0.9670 - val_loss: 0.1006 - val_accuracy: 0.9686
# Epoch 77/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1070 - accuracy: 0.9678 - val_loss: 0.0995 - val_accuracy: 0.9701
# Epoch 78/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1102 - accuracy: 0.9666 - val_loss: 0.1029 - val_accuracy: 0.9685
# Epoch 79/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1096 - accuracy: 0.9675 - val_loss: 0.1007 - val_accuracy: 0.9695
# Epoch 80/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1105 - accuracy: 0.9667 - val_loss: 0.1018 - val_accuracy: 0.9689
# Epoch 81/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1063 - accuracy: 0.9676 - val_loss: 0.1033 - val_accuracy: 0.9683
# Epoch 82/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1054 - accuracy: 0.9681 - val_loss: 0.0993 - val_accuracy: 0.9697
# Epoch 83/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1040 - accuracy: 0.9693 - val_loss: 0.0963 - val_accuracy: 0.9709
# Epoch 84/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.1034 - accuracy: 0.9692 - val_loss: 0.0918 - val_accuracy: 0.9719
# Epoch 85/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1025 - accuracy: 0.9693 - val_loss: 0.0978 - val_accuracy: 0.9722
# Epoch 86/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.1010 - accuracy: 0.9708 - val_loss: 0.0953 - val_accuracy: 0.9718
# Epoch 87/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0982 - accuracy: 0.9708 - val_loss: 0.0919 - val_accuracy: 0.9723
# Epoch 88/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0989 - accuracy: 0.9703 - val_loss: 0.0883 - val_accuracy: 0.9724
# Epoch 89/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0947 - accuracy: 0.9722 - val_loss: 0.0821 - val_accuracy: 0.9753
# Epoch 90/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0954 - accuracy: 0.9720 - val_loss: 0.0830 - val_accuracy: 0.9756
# Epoch 91/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0916 - accuracy: 0.9729 - val_loss: 0.0844 - val_accuracy: 0.9758
# Epoch 92/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0920 - accuracy: 0.9734 - val_loss: 0.0906 - val_accuracy: 0.9750
# Epoch 93/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0923 - accuracy: 0.9730 - val_loss: 0.0835 - val_accuracy: 0.9757
# Epoch 94/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0903 - accuracy: 0.9741 - val_loss: 0.0882 - val_accuracy: 0.9732
# Epoch 95/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0877 - accuracy: 0.9744 - val_loss: 0.0812 - val_accuracy: 0.9770
# Epoch 96/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0880 - accuracy: 0.9748 - val_loss: 0.0781 - val_accuracy: 0.9780
# Epoch 97/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0896 - accuracy: 0.9741 - val_loss: 0.0817 - val_accuracy: 0.9764
# Epoch 98/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0896 - accuracy: 0.9743 - val_loss: 0.0832 - val_accuracy: 0.9748
# Epoch 99/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0882 - accuracy: 0.9750 - val_loss: 0.0932 - val_accuracy: 0.9720
# Epoch 100/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0861 - accuracy: 0.9757 - val_loss: 0.0866 - val_accuracy: 0.9741
# Epoch 101/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0869 - accuracy: 0.9746 - val_loss: 0.0985 - val_accuracy: 0.9706
# Epoch 102/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0921 - accuracy: 0.9735 - val_loss: 0.0827 - val_accuracy: 0.9766
# Epoch 103/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0875 - accuracy: 0.9752 - val_loss: 0.0775 - val_accuracy: 0.9774
# Epoch 104/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0879 - accuracy: 0.9754 - val_loss: 0.0766 - val_accuracy: 0.9787
# Epoch 105/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0877 - accuracy: 0.9745 - val_loss: 0.0761 - val_accuracy: 0.9780
# Epoch 106/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0862 - accuracy: 0.9752 - val_loss: 0.0777 - val_accuracy: 0.9781
# Epoch 107/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0886 - accuracy: 0.9745 - val_loss: 0.0757 - val_accuracy: 0.9782
# Epoch 108/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0862 - accuracy: 0.9760 - val_loss: 0.0855 - val_accuracy: 0.9743
# Epoch 109/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0853 - accuracy: 0.9758 - val_loss: 0.0748 - val_accuracy: 0.9788
# Epoch 110/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0870 - accuracy: 0.9752 - val_loss: 0.0805 - val_accuracy: 0.9764
# Epoch 111/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0852 - accuracy: 0.9759 - val_loss: 0.0804 - val_accuracy: 0.9775
# Epoch 112/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0861 - accuracy: 0.9747 - val_loss: 0.0805 - val_accuracy: 0.9776
# Epoch 113/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0866 - accuracy: 0.9748 - val_loss: 0.0960 - val_accuracy: 0.9710
# Epoch 114/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0859 - accuracy: 0.9753 - val_loss: 0.1004 - val_accuracy: 0.9671
# Epoch 115/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0841 - accuracy: 0.9762 - val_loss: 0.0768 - val_accuracy: 0.9781
# Epoch 116/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0870 - accuracy: 0.9749 - val_loss: 0.0778 - val_accuracy: 0.9780
# Epoch 117/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0833 - accuracy: 0.9755 - val_loss: 0.0758 - val_accuracy: 0.9780
# Epoch 118/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0851 - accuracy: 0.9752 - val_loss: 0.0759 - val_accuracy: 0.9780
# Epoch 119/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0854 - accuracy: 0.9757 - val_loss: 0.0919 - val_accuracy: 0.9734
# Epoch 120/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0851 - accuracy: 0.9752 - val_loss: 0.0768 - val_accuracy: 0.9777
# Epoch 121/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0843 - accuracy: 0.9760 - val_loss: 0.0789 - val_accuracy: 0.9769
# Epoch 122/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0844 - accuracy: 0.9757 - val_loss: 0.0809 - val_accuracy: 0.9767
# Epoch 123/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0859 - accuracy: 0.9755 - val_loss: 0.0753 - val_accuracy: 0.9785
# Epoch 124/200
# 760/760 [==============================] - 1s 1ms/step - loss: 0.0828 - accuracy: 0.9765 - val_loss: 0.0852 - val_accuracy: 0.9765
# Epoch 125/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0844 - accuracy: 0.9762 - val_loss: 0.0769 - val_accuracy: 0.9779
# Epoch 126/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0854 - accuracy: 0.9759 - val_loss: 0.0753 - val_accuracy: 0.9790
# Epoch 127/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0853 - accuracy: 0.9752 - val_loss: 0.0762 - val_accuracy: 0.9778
# Epoch 128/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0848 - accuracy: 0.9760 - val_loss: 0.0884 - val_accuracy: 0.9734
# Epoch 129/200
# 760/760 [==============================] - 1s 2ms/step - loss: 0.0837 - accuracy: 0.9759 - val_loss: 0.0981 - val_accuracy: 0.9720

# %%
plt.plot(history.history['val_loss'],label="val loss")
plt.plot(history.history['loss'],label="loss")
plt.legend()

# %load_ext tensorboard
#rm -rf ./logs/
# %tensorboard --logdir logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.

# %% [markdown]
# ## Create and train a Boosted Decision Tree
# Here, instead of using a MLP, we use a [_Gradient Boosted Decision Tree_](https://xgboost.readthedocs.io/en/stable/) (BDT) to distinguish between signal (true CE hits) and background (fake CE hits). We use the defualt hyperparameters.

# %%
model_xgboost = XGBClassifier(use_label_encoder=False)
model_xgboost.fit(x_ce_train, y_ce_train)
# Out:
# /global/homes/j/jasonguo/.conda/envs/KKTrain2/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# Here we can finally apply our two models (the MLP and the BDT) to our test datasets and create the corresponding ROC curves.

# %%
#prediction_ce = model.predict(x_ce_test).ravel()
prediction_ce = model.predict(x_ce_test)
fpr_ce, tpr_ce, th_ce = roc_curve(y_ce_test,  prediction_ce)
auc_ce = roc_auc_score(y_ce_test, prediction_ce)
# Out:
# 380/380 [==============================] - 0s 656us/step

# %%
prediction_xgboost = model_xgboost.predict_proba(x_ce_test)[:,1]
fpr_xgboost, tpr_xgboost, th_xgboost = roc_curve(y_ce_test,  prediction_xgboost)
auc_xgboost = roc_auc_score(y_ce_test, prediction_xgboost)

# %% [markdown]
# The plot of the ROC curves clearly shows that the BDT outperforms the MLP. In principle, however, it should be possible to improve the MLP performances by optimizing the hyperparameters (learning rate, hidden layers, activation functions, etc.).

# %%
fig, ax = plt.subplots(1,1)
ax.plot(tpr_ce,1-fpr_ce,label=f'MLP AUC: {auc_ce:.4f}')
ax.plot(tpr_xgboost,1-fpr_xgboost,label=f'BDT AUC: {auc_xgboost:.4f}')

ax.legend()
ax.set_aspect("equal")
ax.set_xlabel("Signal efficiency")
ax.set_ylabel("Background rejection")
ax.set_xlim(0.8,1.05)
ax.set_ylim(0.8,1.05)

fig.savefig("plots/TrainBkg" + suffix + ".pdf")

# %% [markdown]
# Now we save our model in HDF5 format.  This can be used as input to the SOFIE parser.  Note that the kernel must be restarted when saving this file, as re-running individual cells increments the layer numbers in the hdf5 file, causing the SOFIE parser to fail.  This causes the spurious tensorflow warning about the model not having been built.

# %%
model.save(modelfile)
print("model saved to " +modelfile)
model.summary()
# Out:
# model saved to models/TrainBkgWithOffsets.h5
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(32, 6)]                 0
#
#  dense_8 (Dense)             (32, 12)                  84
#
#  dense_9 (Dense)             (32, 12)                  156
#
#  dense_10 (Dense)            (32, 12)                  156
#
#  dense_11 (Dense)            (32, 1)                   13
#
# =================================================================
# Total params: 409
# Trainable params: 409
# Non-trainable params: 0
# _________________________________________________________________
